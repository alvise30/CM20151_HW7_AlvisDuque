# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from astropy.io import fits
import pyfits

# %%
hdulist = fits.open('hmi.m_45s.magnetogram.subregion_x1y1.fits')
hdulist2 = pyfits.open('hmi.m_45s.magnetogram.subregion_x1y1.fits')

# %%
hdulist.info()
# Out:
# Filename: hmi.m_45s.magnetogram.subregion_x1y1.fits
# No.    Name         Type      Cards   Dimensions   Format
# 0    PRIMARY     PrimaryHDU     121   (398, 199, 207)   float32

# %%
prihdr = hdulist[0].header

# %% [raw]
# prihdr.keys()

# %%
hdulist[0].data
# Out:
# array([[[  2.64299908e+01,   2.64853573e+01,   2.23794060e+01, ...,
#           -7.20265687e-01,  -6.36949182e-01,  -5.72341979e-01],
#         [  3.22028465e+01,   2.60503788e+01,   2.54185925e+01, ...,
#           -7.01804876e-01,  -5.45920968e-01,  -3.11779171e-01],
#         [  2.79157810e+01,   2.42980099e+01,   3.10286465e+01, ...,
#           -5.61383009e-01,  -1.10042267e-01,   1.84158877e-01],
#         ...,
#         [ -3.57183933e-01,   2.83198785e-02,   4.89380181e-01, ...,
#           -2.68369913e-01,  -1.82896420e-01,  -1.92715153e-01],
#         [  3.79534662e-01,   1.39949620e-01,   7.82552898e-01, ...,
#           -2.21547082e-01,  -1.73526391e-01,  -1.83855236e-01],
#         [ -4.55451123e-02,  -6.91755489e-02,   2.92236693e-02, ...,
#           -5.86365938e-01,  -4.49604422e-01,  -7.24128187e-01]],
#
#        [[  3.14054413e+01,   3.07949810e+01,   2.69229927e+01, ...,
#            9.02718976e-02,   7.54300505e-02,  -5.60316741e-01],
# ...

# %%
hdulist.close()
hdulist2.close()
